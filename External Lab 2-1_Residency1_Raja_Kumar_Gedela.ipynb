# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
#hr_df = pd.read_fwf("HR-1.txt")
#hr_df = pd.read_csv("HR-1.txt", sep=" ")
hr_df = pd.read_csv("HR-1.txt",sep="\t") #delimiter="\t")

# %%
hr_df.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 3        Ind4        No   33               2       1392           2
# 4        Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                 1          2               1              1
# 1                 8          1               1              1
# 2                 2          2               6              1
# 3                 3          4               1              1
# 4                 2          1               2              1
#
#            ...           RelationshipSatisfaction  StandardHours  \
# 0          ...                                  1             80
# 1          ...                                  4             80
# 2          ...                                  2             80
# 3          ...                                  3             80
# 4          ...                                  4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2
#
# [5 rows x 35 columns]

# %%
hr_df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
hr_df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
hr_df.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
hr_df.iloc[:, 3:10]
# Out:
#       BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0                  1       1102           1                 1          2
# 1                  2        279           2                 8          1
# 2                  1       1373           2                 2          2
# 3                  2       1392           2                 3          4
# 4                  1        591           2                 2          1
# 5                  2       1005           2                 2          2
# 6                  1       1324           2                 3          3
# 7                  1       1358           2                24          1
# 8                  2        216           2                23          3
# 9                  1       1299           2                27          3
# 10                 1        809           2                16          3
# 11                 1        153           2                15          2
# 12                 1        670           2                26          1
# 13                 1       1346           2                19          2
# 14                 1        103           2                24          3
# 15                 1       1389           2                21          4
# 16                 1        334           2                 5          2
# 17                 3       1123           2                16          2
# 18                 1       1219           1                 2          4
# 19                 1        371           2                 2          3
# 20                 3        673           2                11          2
# 21                 1       1218           1                 9          4
# 22                 1        419           2                 7          4
# 23                 1        391           2                15          2
# 24                 1        699           2                 6          1
# 25                 1       1282           2                 5          3
# 26                 2       1125           2                16          1
# 27                 1        691           1                 8          4
# 28                 1        477           2                 7          4
# 29                 1        705           1                 2          4
# ...              ...        ...         ...               ...        ...
# 1440               2        688           2                 4          2
# 1441               3        667           2                 1          4
# 1442               1       1092           2                 1          4
# 1443               1        300           2                 2          3
# 1444               1        310           2                 7          2
# 1445               1        582           2                28          4
# 1446               1        704           1                28          3
# 1447               3        301           1                15          4
# 1448               1        930           1                 3          3
# 1449               1        529           2                 2          3
# 1450               1       1146           3                26          4
# 1451               1        345           1                10          2
# 1452               2        878           1                 1          4
# 1453               1       1120           1                11          4
# 1454               1        374           1                20          3
# 1455               1       1322           2                 2          4
# 1456               2       1199           2                18          4
# 1457               1       1194           2                 2          4
# 1458               1        287           2                 1          4
# 1459               1       1378           2                13          2
# 1460               1        468           2                28          4
# 1461               1        410           1                28          3
# 1462               1        722           1                24          1
# 1463               3        325           2                 5          3
# 1464               1       1167           1                 5          3
# 1465               2        884           2                23          2
# 1466               1        613           2                 6          1
# 1467               1        155           2                 4          3
# 1468               2       1023           1                 2          3
# 1469               1        628           2                 8          3
#
#       EducationField  EmployeeCount
# 0                  1              1
# 1                  1              1
# 2                  6              1
# 3                  1              1
# 4                  2              1
# 5                  1              1
# 6                  2              1
# 7                  1              1
# 8                  1              1
# 9                  2              1
# 10                 2              1
# 11                 1              1
# 12                 1              1
# 13                 2              1
# 14                 1              1
# 15                 1              1
# 16                 1              1
# 17                 2              1
# 18                 1              1
# 19                 1              1
# 20                 6              1
# 21                 1              1
# 22                 1              1
# 23                 1              1
# 24                 2              1
# 25                 6              1
# 26                 1              1
# 27                 3              1
# 28                 2              1
# 29                 3              1
# ...              ...            ...
# 1440               1              1
# 1441               1              1
# 1442               2              1
# 1443               1              1
# 1444               4              1
# 1445               1              1
# 1446               3              1
# 1447               3              1
# 1448               1              1
# 1449               4              1
# 1450               1              1
# 1451               1              1
# 1452               1              1
# 1453               3              1
# 1454               1              1
# 1455               1              1
# 1456               1              1
# 1457               2              1
# 1458               1              1
# 1459               6              1
# 1460               2              1
# 1461               3              1
# 1462               3              1
# 1463               2              1
# 1464               6              1
# 1465               2              1
# 1466               2              1
# 1467               1              1
# 1468               2              1
# 1469               2              1
#
# [1470 rows x 7 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
hr_df.groupby('Gender').count()
# Out:
#         Individual   Attrition  Age  BusinessTravel  DailyRate  Department  \
# Gender
# 1               882        882  882             882        882         882
# 2               588        588  588             588        588         588
#
#         DistanceFromHome  Education  EducationField  EmployeeCount  \
# Gender
# 1                    882        882             882            882
# 2                    588        588             588            588
#
#                 ...           RelationshipSatisfaction  StandardHours  \
# Gender          ...
# 1               ...                                882            882
# 2               ...                                588            588
#
#         StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# Gender
# 1                    882                882                    882
# 2                    588                588                    588
#
#         WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Gender
# 1                   882             882                 882
# 2                   588             588                 588
#
#         YearsSinceLastPromotion  YearsWithCurrManager
# Gender
# 1                           882                   882
# 2                           588                   588
#
# [2 rows x 34 columns]

# %%
males_df = hr_df[hr_df.Gender == 1]
males_df['Gender'].count()
# Out:
# 882

# %%
females_df = hr_df[hr_df.Gender == 2]
females_df['Age'].count()
# Out:
# 588

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
hr_df.describe()
# Out:
#                Age  BusinessTravel    DailyRate   Department  \
# count  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810        1.392517   802.485714     1.739456
# std       9.135373        0.665455   403.509100     0.527792
# min      18.000000        1.000000   102.000000     1.000000
# 25%      30.000000        1.000000   465.000000     1.000000
# 50%      36.000000        1.000000   802.000000     2.000000
# 75%      43.000000        2.000000  1157.000000     2.000000
# max      60.000000        3.000000  1499.000000     3.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           9.192517     2.912925        2.153741            1.0
# std            8.106864     1.024165        1.383865            0.0
# min            1.000000     1.000000        1.000000            1.0
# 25%            2.000000     2.000000        1.000000            1.0
# 50%            7.000000     3.000000        2.000000            1.0
# 75%           14.000000     4.000000        3.000000            1.0
# max           29.000000     5.000000        6.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction          ...           \
# count     1470.000000              1470.000000          ...
# mean      1024.865306                 2.721769          ...
# std        602.024335                 1.093082          ...
# min          1.000000                 1.000000          ...
# 25%        491.250000                 2.000000          ...
# 50%       1020.500000                 3.000000          ...
# 75%       1555.750000                 4.000000          ...
# max       2068.000000                 4.000000          ...
#
#        RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# count               1470.000000         1470.0       1470.000000
# mean                   2.712245           80.0          0.793878
# std                    1.081209            0.0          0.852077
# min                    1.000000           80.0          0.000000
# 25%                    2.000000           80.0          0.000000
# 50%                    3.000000           80.0          1.000000
# 75%                    4.000000           80.0          1.000000
# max                    4.000000           80.0          3.000000
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count        1470.000000            1470.000000      1470.000000
# mean           11.279592               2.799320         2.761224
# std             7.780782               1.289271         0.706476
# min             0.000000               0.000000         1.000000
# 25%             6.000000               2.000000         2.000000
# 50%            10.000000               3.000000         3.000000
# 75%            15.000000               3.000000         3.000000
# max            40.000000               6.000000         4.000000
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count     1470.000000         1470.000000              1470.000000
# mean         7.008163            4.229252                 2.187755
# std          6.126525            3.623137                 3.222430
# min          0.000000            0.000000                 0.000000
# 25%          3.000000            2.000000                 0.000000
# 50%          5.000000            3.000000                 1.000000
# 75%          9.000000            7.000000                 3.000000
# max         40.000000           18.000000                15.000000
#
#        YearsWithCurrManager
# count           1470.000000
# mean               4.123129
# std                3.568136
# min                0.000000
# 25%                2.000000
# 50%                3.000000
# 75%                7.000000
# max               17.000000
#
# [8 rows x 33 columns]

# %%
hr_df['Age'].quantile(0.75)
# Out:
# 43.0

# %%
hr_df['Age'].quantile(0.25)
# Out:
# 30.0

# %%
iqr_age = hr_df['Age'].quantile(0.75) - hr_df['Age'].quantile(0.25)
iqr_age
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
hr_df['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
hr_df['DailyRate'].median()
# Out:
# 802.0

# %%
hr_df['DailyRate'].var()
# Out:
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, use histogram to plot the data)

# %%
import matplotlib.pyplot as plt
#import matplotlib.style as sty

#sty.use('ggplot')

# %%
#plt.hist(hr_df.Attrition)
#pl.show()
hr_df['Attrition'].head()
hr_df_atr = hr_df['Attrition']
hr_df_atr_20 = hr_df_atr.head(20) # It is taking lot of time for all values; so, i have selected only 20 values

# %%
hr_df_atr_20
# Out:
# 0     Yes
# 1      No
# 2     Yes
# 3      No
# 4      No
# 5      No
# 6      No
# 7      No
# 8      No
# 9      No
# 10     No
# 11     No
# 12     No
# 13     No
# 14    Yes
# 15     No
# 16     No
# 17     No
# 18     No
# 19     No
# Name: Attrition, dtype: object

# %%
plt.hist(hr_df_atr_20)    
plt.show()

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
plt.plot(hr_df.TotalWorkingYears)

# %% [markdown]
# ### Create 500 random samples from normal distribution with mean 1 and  standard deviation 0.5

# %%
np.random.seed(20190502)
mu, sigma = 1, 0.5
x = mu + sigma * np.random.randn(500)

# %% [markdown]
# ###  Plot the histogram of the above normal distribution

# %%
plt.hist(x)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Histogram of Data')
plt.show()
